# %%
from typing import Any, Dict

import pandas as pd

# %%
def extract_url(tweet: pd.Series, url_dict: Dict[str, int]):
    if isinstance(tweet["entities"], dict):
        for url_entity in tweet["entities"].get("urls", list()):
            url = url_entity["expanded_url"]
            if url in url_dict:
                url_dict[url]["Count"] += 1
            else:
                url_dict[url] = {"Count": 1, "CreatedAt": tweet["created_at"]}

# %%
start_date = "20230203"
end_date = "20230228"
tweet_count = dict()
url_dict = dict()

for date in pd.date_range(start_date, end_date):
    date = date.strftime("%Y%m%d")
    df = pd.read_pickle(f"../data/twitter/pkl/{date}_data.pkl", compression="gzip").sort_values(["created_at"])
    tweet_count[date] = len(df)
    df.apply(lambda tweet: extract_url(tweet, url_dict), axis=1)
tweet_count = pd.Series(tweet_count).sort_index()
tweet_count.index = pd.DatetimeIndex(tweet_count.index)
tweet_count.plot(figsize=(10, 5), grid=True)

# %%
df_urls = pd.DataFrame({key: [val["Count"], val["CreatedAt"]] for key, val in url_dict.items()}).T
df_urls.columns = ["Count", "CreatedAt"]
df_urls = df_urls.sort_values(["Count"], ascending=False)
df_urls["Domain"] = df_urls.apply(lambda url:"/".join(url.name.split("/")[:3]), axis=1)
df_urls.index.name = "URL"
df_urls
# Out:
#                                                     Count  \
# https://twitter.com/nicksortor/status/162632783...  15082
# https://twitter.com/Ultrademic/status/162495870...  10991
# https://twitter.com/realstewpeters/status/16252...  10478
# https://twitter.com/JackPosobiec/status/1628430...   9517
# https://twitter.com/realstewpeters/status/16263...   9280
# ...                                                   ...
# https://www.i24news.tv/en/news/international/am...      1
# https://www.knopnews2.com/2023/02/18/donald-tru...      1
# https://eu.dispatch.com/story/news/local/2023/0...      1
# https://twitter.com/xformed/status/162674121740...      1
# https://twitter.com/ada_lluch/status/1630692167...      1
#
#                                                                    CreatedAt  \
# https://twitter.com/nicksortor/status/162632783...  2023-02-16T21:09:06.000Z
# https://twitter.com/Ultrademic/status/162495870...  2023-02-13T02:28:40.000Z
# https://twitter.com/realstewpeters/status/16252...  2023-02-13T23:04:45.000Z
# https://twitter.com/JackPosobiec/status/1628430...  2023-02-22T16:22:21.000Z
# https://twitter.com/realstewpeters/status/16263...  2023-02-17T00:25:10.000Z
# ...                                                                      ...
# https://www.i24news.tv/en/news/international/am...  2023-02-18T01:34:14.000Z
# https://www.knopnews2.com/2023/02/18/donald-tru...  2023-02-18T01:34:02.000Z
# https://eu.dispatch.com/story/news/local/2023/0...  2023-02-18T01:33:59.000Z
# https://twitter.com/xformed/status/162674121740...  2023-02-18T01:33:50.000Z
# https://twitter.com/ada_lluch/status/1630692167...  2023-02-28T23:59:35.000Z
#
#                                                                        Domain
# https://twitter.com/nicksortor/status/162632783...        https://twitter.com
# https://twitter.com/Ultrademic/status/162495870...        https://twitter.com
# https://twitter.com/realstewpeters/status/16252...        https://twitter.com
# https://twitter.com/JackPosobiec/status/1628430...        https://twitter.com
# https://twitter.com/realstewpeters/status/16263...        https://twitter.com
# ...                                                                       ...
# https://www.i24news.tv/en/news/international/am...     https://www.i24news.tv
# https://www.knopnews2.com/2023/02/18/donald-tru...  https://www.knopnews2.com
# https://eu.dispatch.com/story/news/local/2023/0...    https://eu.dispatch.com
# https://twitter.com/xformed/status/162674121740...        https://twitter.com
# https://twitter.com/ada_lluch/status/1630692167...        https://twitter.com
#
# [110467 rows x 3 columns]

# %%
df_urls.to_csv("../data/twitter/URL.csv", sep="\t", index_label="URL")

# %%
df_urls.groupby(["Domain"]).count().sort_values(["Count"], ascending=False).head(5)
# Out:
#                      Count  CreatedAt
# Domain
# https://twitter.com  59348      59348
# http://dlvr.it        2218       2218
# https://youtu.be      1521       1521
# https://www.msn.com   1409       1409
# https://ift.tt        1366       1366

# %%
df_urls[df_urls["Domain"].str.startswith("https://www.msn.com")].head(5)
# Out:
#                                                    Count  \
# URL
# https://www.msn.com/en-us/news/other/trump-to-v...   256
# https://www.msn.com/en-us/news/politics/ohio-tr...    55
# https://www.msn.com/en-us/news/politics/trump-r...    34
# https://www.msn.com/en-us/news/us/fema-withhold...    29
# https://www.msn.com/en-us/news/politics/trump-w...    24
#
#                                                                    CreatedAt  \
# URL
# https://www.msn.com/en-us/news/other/trump-to-v...  2023-02-17T23:41:42.000Z
# https://www.msn.com/en-us/news/politics/ohio-tr...  2023-02-22T18:34:21.000Z
# https://www.msn.com/en-us/news/politics/trump-r...  2023-02-23T12:52:55.000Z
# https://www.msn.com/en-us/news/us/fema-withhold...  2023-02-17T04:06:24.000Z
# https://www.msn.com/en-us/news/politics/trump-w...  2023-02-23T01:28:25.000Z
#
#                                                                  Domain
# URL
# https://www.msn.com/en-us/news/other/trump-to-v...  https://www.msn.com
# https://www.msn.com/en-us/news/politics/ohio-tr...  https://www.msn.com
# https://www.msn.com/en-us/news/politics/trump-r...  https://www.msn.com
# https://www.msn.com/en-us/news/us/fema-withhold...  https://www.msn.com
# https://www.msn.com/en-us/news/politics/trump-w...  https://www.msn.com
